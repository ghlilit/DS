# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data.csv')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    BPrev  BStreak  B_Age  B_Height                          B_HomeTown  B_ID  \
# 0      1        1   23.0     182.0                        Trento Italy  2783
# 1      0        0   32.0     175.0  Careiro da Várzea, Amazonas Brazil  2208
# 2      2        0   38.0     172.0                      Kanagawa Japan   721
# 3      0        0   23.0     170.0                      Tijuana Mexico  2825
# 4      3        1   30.0     167.0                     Spokane, WA USA  2260
#
#           B_Location                 B_Name  B_Weight  \
# 0  Mezzocorona Italy         Marvin Vettori        84
# 1   Pharr, Texas USA  Carlos Diego Ferreira        70
# 2        Tokyo Japan          Takanori Gomi        70
# 3     Tijuana Mexico         Brandon Moreno        56
# 4    Spokane, WA USA     Elizabeth Phillips        61
#
#    B__Round1_Grappling_Reversals_Landed  B__Round1_Grappling_Standups_Landed  \
# 0                                   0.0                                  1.0
# ...

# %%
# Dropping the columns which contain only one instance per category
df.drop(columns=['B_ID','Event_ID','Fight_ID', 'B_Name','R_ID','R_Name'], inplace=True)

# %%
df.info(max_cols=1000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1477 entries, 0 to 1476
# Data columns (total 889 columns):
#  #    Column                                                 Non-Null Count  Dtype
# ---   ------                                                 --------------  -----
#  0    BPrev                                                  1477 non-null   int64
#  1    BStreak                                                1477 non-null   int64
#  2    B_Age                                                  1474 non-null   float64
#  3    B_Height                                               1476 non-null   float64
#  4    B_HomeTown                                             1471 non-null   object
#  5    B_Location                                             1470 non-null   object
#  6    B_Weight                                               1477 non-null   int64
#  7    B__Round1_Grappling_Reversals_Landed                   978 non-null    float64
# ...

# %% [markdown]
# # Cleaning Categorical features
# Handle missing data for continuous columns only. Assume we will use a model that can work with missing data.

# %%
df.describe(include="object")
# Out:
#                    B_HomeTown             B_Location        Date  \
# count                    1471                   1470        1477
# unique                    568                    431         224
# top     Rio de Janeiro Brazil  Rio de Janeiro Brazil  12/14/2015
# freq                       32                     38          32
#
#                    R_HomeTown             R_Location winby winner
# count                    1477                   1476  1461   1477
# unique                    495                    390     3      4
# top     Rio de Janeiro Brazil  Rio de Janeiro Brazil   DEC    red
# freq                       44                     67   720    867

# %%
print(sum(df['Date'].isna()))
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# 0

# %%
sum(df['B_HomeTown'].isna()), sum(df['B_Location'].isna()), sum(df['R_HomeTown'].isna()), sum(df['R_Location'].isna())
# Out:
# (6, 7, 0, 1)

# %%
sum(df['B_HomeTown'] == df['B_Location']) , sum(df['R_HomeTown'] == df['R_Location'])
# Out:
# (468, 448)

# %%
df['B_Location'].value_counts(dropna=False)
# Out:
# Rio de Janeiro Brazil                  38
# Denver, Colorado USA                   27
# Albuquerque, New Mexico USA            25
# Coconut Creek, Florida USA             21
# Sacramento, California USA             20
#                                        ..
# Chatham, Ontario Canada                 1
# Long Island, New York United States     1
# St. Albert, Alberta Canada              1
# Maha Sarakham Thailand                  1
# Perth, Western Australia Australia      1
# Name: B_Location, Length: 432, dtype: int64

# %%
df['B_HomeTown'].value_counts(dropna=False)
# Out:
# Rio de Janeiro Brazil              32
# Dagestan Russia                    17
# Sao Paulo Brazil                   17
# Los Angeles, California USA        14
# Miami, Florida USA                 11
#                                    ..
# Odzaci Serbia                       1
# Reykjavik Iceland                   1
# Blumenau, Santa Catarina Brazil     1
# Sydney Australia                    1
# Vicosa, Minas Gerais Brazil         1
# Name: B_HomeTown, Length: 569, dtype: int64

# %%
# Creating some new features
df['R_is_moved'] = df['R_HomeTown'] != df['R_Location']
df['R_HomeTown_country'] = df['R_HomeTown'].str.split(' ').str[-1]
df['R_Location_country'] = df['R_Location'].str.split(' ').str[-1]
df['R_is_moved_country'] = df['R_HomeTown_country'] != df['R_Location_country']

df['B_is_moved'] = df['B_HomeTown'] != df['B_Location']
df['B_HomeTown_country'] = df['B_HomeTown'].str.split(' ').str[-1] 
df['B_Location_country'] = df['B_Location'].str.split(' ').str[-1]
df['B_is_moved_country'] = df['B_HomeTown_country'] != df['B_Location_country']

# %%
sum(df['B_HomeTown_country']=='') # this is due to nan values
# Out:
# 2

# %%
df['B_HomeTown_country'].replace('', np.nan, inplace=True)
df['B_Location_country'].replace('', np.nan, inplace=True)
df['R_HomeTown_country'].replace('', np.nan, inplace=True)
df['R_Location_country'].replace('', np.nan, inplace=True)

# %%
# just checking
df[['B_HomeTown_country','B_Location_country','B_is_moved_country','R_HomeTown_country','R_Location_country','R_is_moved_country']]
# Out:
#      B_HomeTown_country B_Location_country  B_is_moved_country  \
# 0                 Italy              Italy               False
# 1                Brazil                USA                True
# 2                 Japan              Japan               False
# 3                Mexico             Mexico               False
# 4                   USA                USA               False
# ...                 ...                ...                 ...
# 1472             Mexico                USA                True
# 1473                USA                USA               False
# 1474                USA                USA               False
# 1475           Scotland           Scotland               False
# 1476        Netherlands        Netherlands               False
#
#      R_HomeTown_country R_Location_country  R_is_moved_country
# 0                Brazil             States                True
# 1                   USA                USA               False
# ...

# %%
def keep_common_categories(df, columns, percent = 0.7, value = 'other'):
    for column in columns:
        l = len(df[column].unique())
        not_common_categories = df[column].value_counts(dropna=False)[int(l*percent):].index
        for c in not_common_categories:
            df[column].replace(c, value, inplace=True)

# %%
columns=['B_HomeTown','B_Location','B_HomeTown_country','B_Location_country',
        'R_HomeTown','R_Location','R_HomeTown_country','R_Location_country']
keep_common_categories(df, columns)

# %%
df['B_Location'].value_counts(dropna=False)
# Out:
# other                                         132
# Rio de Janeiro Brazil                          38
# Denver, Colorado USA                           27
# Albuquerque, New Mexico USA                    25
# Coconut Creek, Florida USA                     21
#                                              ...
# Minas Gerais Brazil                             2
# Rancho Cucamonga, California United States      2
# Des Moines, IA USA                              2
# Honolulu, Hawaii USA                            2
# Queens, New York United States                  2
# Name: B_Location, Length: 303, dtype: int64

# %% [markdown]
# # Bin the data for columns ‘R_Weight’ and ‘B_Weight’.

# %%
sum(df['R_Weight'].isna())
# Out:
# 0

# %%
def binning(df, columns, bin_count, labels):
    for i,column in enumerate(columns):
        min_value = df[column].min()
        max_value = df[column].max()
        bins = np.linspace(min_value, max_value, bin_count[i]+1)
        df[column+'_bins'] = pd.cut(df[column], bins=bins, labels=labels[i], include_lowest=True)

# %%
binning(
    df,
    columns = ['R_Weight','B_Weight'], 
    bin_count = [3,3], # in case you want different bin sizes
    labels = [['lightweight','middleweight','heavyweight'],
              ['lightweight','middleweight','heavyweight']]) # in case you want different labels

# %%
df[['B_Weight','B_Weight_bins','R_Weight','R_Weight_bins']]
# Out:
#       B_Weight B_Weight_bins  R_Weight R_Weight_bins
# 0           84  middleweight        84  middleweight
# 1           70   lightweight        70   lightweight
# 2           70   lightweight        70   lightweight
# 3           56   lightweight        56   lightweight
# 4           61   lightweight        61   lightweight
# ...        ...           ...       ...           ...
# 1472        61   lightweight        61   lightweight
# 1473        56   lightweight        56   lightweight
# 1474        93  middleweight        84  middleweight
# 1475        52   lightweight        56   lightweight
# 1476        84  middleweight        84  middleweight
#
# [1477 rows x 4 columns]

# %%
df['R_Weight_bins'].dtype
# Out:
# CategoricalDtype(categories=['lightweight', 'middleweight', 'heavyweight'], ordered=True)

# %% [markdown]
# # Handling missing values

# %%
df_int = df.select_dtypes(include=["integer"])

# %%
df_int.isna().sum()
# there are no missing values in integer columns
# Out:
# BPrev         0
# BStreak       0
# B_Weight      0
# Last_round    0
# Max_round     0
# RPrev         0
# RStreak       0
# R_Height      0
# R_Weight      0
# dtype: int64

# %%
float_cols = df.select_dtypes(include=["floating"]).columns.values

# %%
df.select_dtypes(include=["floating"]).isna().sum().sort_values()
# Out:
# B_Height                                           1
# R_Age                                              1
# B_Age                                              3
# R__Round1_Strikes_Kicks_Attempts                 342
# R__Round1_Strikes_Head Total Strikes_Landed      342
#                                                 ...
# R__Round4_Strikes_Leg Total Strikes_Attempts    1450
# B__Round4_Strikes_Leg Total Strikes_Attempts    1471
# B__Round5_Strikes_Leg Total Strikes_Landed      1471
# B__Round5_Strikes_Leg Total Strikes_Attempts    1471
# B__Round4_Strikes_Leg Total Strikes_Landed      1471
# Length: 873, dtype: int64

# %%
thresh=int(df.shape[0]*0.4)
df.drop(columns=float_cols[df[float_cols].isna().sum()>thresh], inplace = True)

# %%
df.select_dtypes(include=["floating"]).isna().sum().sort_values()
# Out:
# R_Age                                                1
# B_Height                                             1
# B_Age                                                3
# R__Round1_TIP_Side Control Time                    342
# R__Round1_Strikes_Clinch Total Strikes_Landed      342
#                                                   ...
# R__Round3_Strikes_Distance Body Kicks_Attempts     568
# R__Round3_Strikes_Clinch Total Strikes_Landed      568
# R__Round3_Strikes_Clinch Total Strikes_Attempts    568
# R__Round3_Strikes_Distance Head Kicks_Attempts     568
# R__Round3_TIP_Standing Time                        568
# Length: 341, dtype: int64

# %%
df.shape
# Out:
# (1477, 367)

# %%
def fill(df, columns, method='mean'):
    for column in columns:
        if method == 'mode':
            df[column].fillna(df[column].mode()[0], inplace = True)
        else:
            df[column].fillna(df[column].mean(), inplace = True)

# %%
columns = df.select_dtypes(include=["floating"]).isna().columns.values
fill(df, columns[:170])
fill(df, columns[170:], method = 'mode')

# %%
df.select_dtypes(include=["floating"]).isna().sum().sort_values()
# Out:
# B_Age                                                    0
# R__Round2_Strikes_Head Total Strikes_Landed              0
# R__Round2_Strikes_Head Total Strikes_Attempts            0
# R__Round2_Strikes_Head Significant Strikes_Landed        0
# R__Round2_Strikes_Head Significant Strikes_Attempts      0
#                                                         ..
# R__Round1_Strikes_Clinch Total Strikes_Attempts          0
# R__Round1_Strikes_Clinch Significant Strikes_Landed      0
# R__Round1_Strikes_Clinch Significant Strikes_Attempts    0
# R__Round1_Strikes_Distance Body Strikes_Attempts         0
# R__Round3_TIP_Standing Time                              0
# Length: 341, dtype: int64

# %%
df.isna().sum().sort_values()[::-1][:8] # these are catecorigal features
# Out:
# winby                                                16
# B_Location_country                                    9
# B_HomeTown_country                                    8
# B_Location                                            7
# B_HomeTown                                            6
# R_HomeTown_country                                    3
# R_Location_country                                    2
# R__Round1_Strikes_Clinch Significant Kicks_Landed     0
# dtype: int64

# %% [markdown]
# # Spliting and saving the data

# %%
df = pd.get_dummies(data=df, drop_first=True)

# %%
train, test = train_test_split(df)

# %%
train.to_csv('train.csv', index=False)
train.to_csv('test.csv', index=False)
